# %%
#1
f = open("python.txt",'r')

#2 (CHANGE N WITH ANY INT NUMBER)
lines = f.readlines()

lines[n]
#3 (CHANGE N WITH ANY INT NUMBER)

lines[-n]

#4
with open("python.txt") as g:
    data = g.read()
    data.replace(",", " ")

print(len(data.split(" ")))
# Out:
# 100
